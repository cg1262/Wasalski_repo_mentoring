# %%
# imports
from Core.ELTNewrelic.ServicesNewrelic.ServiceNewrelicBronze import ServiceBronze
bronze = ServiceBronze()

# %%
test_billing = bronze.test_billing()

# %%
nrql_percentage = bronze.nrql_percentage()

# %%
success_of_neuron_us = bronze.success_of_neuron_us()

# %%
success_of_neuron_eun = bronze.success_of_neuron_eun()

# %%
documents_stuck_in_ai = bronze.documents_stuck_in_ai()

# %%
no_of_entered_documents = bronze.no_of_entered_documents()

# %%
avg_neuron_e2e_duration_us = bronze.avg_neuron_e2e_duration_us()

# %%
avg_neuron_e2e_duration_eun = bronze.avg_neuron_e2e_duration_eun()

# %%
overall_succ_rate_of_vis_us = bronze.overall_succ_rate_of_vis_us()

# %%
overall_succ_rate_of_vis_eun = bronze.overall_succ_rate_of_vis_eun()

# %%
documents_us_data = bronze.documents_us_data()

# %%
documents_eun_data = bronze.documents_eun_data()

# %%
avg_duraiton_us = bronze.avg_duraiton_us()

# %%
avg_duraiton_eun = bronze.avg_duraiton_eun()

# %%
documents_entered_us = bronze.documents_entered_us()

# %%
documents_entered_eun = bronze.documents_entered_eun()
